# %%
import protospacers
reload(protospacers)
# Out:
# <module 'protospacers' from 'protospacers.py'>

# %%
datadirpath = "/home/user/r/crispreating/data/"

# %%
# %time cuts_yeast = protospacers.digest_directory(datadirpath + "scaffolds_yeast", 'fasta')
len(cuts_yeast), cuts_yeast
# Out:
# CPU times: user 28 ms, sys: 0 ns, total: 28 ms
# Wall time: 25.5 ms
# (2156,
#  ['chrI\t1089\t1109\tBfaI\t1000\t+\n',
#   'chrI\t1112\t1132\tBfaI\t1000\t-\n',
#   'chrI\t1273\t1293\tBfaI\t1000\t+\n',
#   'chrI\t1296\t1316\tBfaI\t1000\t-\n',
#   'chrI\t1786\t1806\tBfaI\t1000\t+\n',
#   'chrI\t1809\t1829\tBfaI\t1000\t-\n',
#   'chrI\t2076\t2096\tBfaI\t1000\t+\n',
#   'chrI\t2099\t2119\tBfaI\t1000\t-\n',
#   'chrI\t3062\t3082\tBfaI\t1000\t+\n',
#   'chrI\t3085\t3105\tBfaI\t1000\t-\n',
#   'chrI\t3958\t3978\tBfaI\t1000\t+\n',
#   'chrI\t3981\t4001\tBfaI\t1000\t-\n',
#   'chrI\t4116\t4136\tBfaI\t1000\t+\n',
#   'chrI\t4139\t4159\tBfaI\t1000\t-\n',
#   'chrI\t5164\t5184\tBfaI\t1000\t+\n',
#   'chrI\t5187\t5207\tBfaI\t1000\t-\n',
#   'chrI\t5849\t5869\tBfaI\t1000\t+\n',
#   'chrI\t5872\t5892\tBfaI\t1000\t-\n',
#   'chrI\t6084\t6104\tBfaI\t1000\t+\n',
#   'chrI\t6107\t6127\tBfaI\t1000\t-\n',
#   'chrI\t6213\t6233\tBfaI\t1000\t+\n',
#   'chrI\t6236\t6256\tBfaI\t1000\t-\n',
# ...

# %%
# %time cuts_ecoliK12DH10b = protospacers.digest_directory(datadirpath + "scaffolds_ecoliK12DH10b", 'fastq.gz')
len(cuts_ecoliK12DH10b), cuts_ecoliK12DH10b
# Out:
# CPU times: user 15.4 s, sys: 112 ms, total: 15.5 s
# Wall time: 15.4 s
# (56408,
#  ['COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:8236:1109\t13\t33\tHpaII\t1000\t+\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:8236:1109\t36\t56\tHpaII\t1000\t-\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:8236:1109\t13\t33\tScrFI\t1000\t+\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:8236:1109\t35\t55\tScrFI\t1000\t-\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:5765:1109\t16\t36\tHpaII\t1000\t+\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:5765:1109\t39\t59\tHpaII\t1000\t-\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:5765:1109\t17\t37\tScrFI\t1000\t+\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:5765:1109\t39\t59\tScrFI\t1000\t-\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:14825:1112\t-10\t10\tHpaII\t1000\t+\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:14825:1112\t13\t33\tHpaII\t1000\t-\n',
#   'COnfig376vm0a:305:FCPE51X7X51Denovo:1:1:2690:1116\t7\t27\tHpaII\t1000\t+\n',
# ...

# %%
# %time cuts_xenopuslaevis = protospacers.digest_directory(datadirpath + "scaffolds_xenopuslaevis", 'fasta')
len(cuts_xenopuslaevis), cuts_xenopuslaevis

# %%
# %time  cuts_hg38chr21_1Mbp = protospacers.digest_directory(datadirpath + "scaffolds_hg38chr21_1Mbp", "fasta")
len(cuts_hg38chr21_1Mbp), cuts_hg38chr21_1Mbp
# Out:
# CPU times: user 88 ms, sys: 4 ms, total: 92 ms
# Wall time: 91 ms
# (18112,
#  ['gi|568815577:42434053-43231744\t376\t396\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t399\t419\tBfaI\t1000\t-\n',
#   'gi|568815577:42434053-43231744\t430\t450\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t453\t473\tBfaI\t1000\t-\n',
#   'gi|568815577:42434053-43231744\t899\t919\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t922\t942\tBfaI\t1000\t-\n',
#   'gi|568815577:42434053-43231744\t939\t959\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t962\t982\tBfaI\t1000\t-\n',
#   'gi|568815577:42434053-43231744\t962\t982\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t985\t1005\tBfaI\t1000\t-\n',
#   'gi|568815577:42434053-43231744\t1088\t1108\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t1111\t1131\tBfaI\t1000\t-\n',
#   'gi|568815577:42434053-43231744\t3018\t3038\tBfaI\t1000\t+\n',
#   'gi|568815577:42434053-43231744\t3041\t3061\tBfaI\t1000\t-\n',
# ...

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_yeast/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 32 ms, sys: 20 ms, total: 52 ms
# Wall time: 84.3 ms

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_hg18chr21_AP001625/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 20 ms, sys: 28 ms, total: 48 ms
# Wall time: 83 ms
# index file /home/user/r/crispreating/data/scaffolds_hg18chr21_AP001625/cat.fasta.fai not found, generating...

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_hg38chr21_1Mbp/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 88 ms, sys: 28 ms, total: 116 ms
# Wall time: 216 ms

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_hg38chr21_1Mbp/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 88 ms, sys: 28 ms, total: 116 ms
# Wall time: 216 ms

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_ecoliK12DH10B/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 528 ms, sys: 28 ms, total: 556 ms
# Wall time: 938 ms

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_xenopuslaevis_Scaffold102974/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 1.66 s, sys: 68 ms, total: 1.72 s
# Wall time: 2.69 s
# index file /home/user/r/crispreating/data/scaffolds_xenopuslaevis_Scaffold102974/cat.fasta.fai not found, generating...

# %%
# %time protospacers.protospacers_bedfile_and_fastafile_from_directory(datadirpath + "scaffolds_xenopuslaevis/", 'fasta')
# Out:
# bed done
# fasta done
# all done
# CPU times: user 5min 5s, sys: 8.88 s, total: 5min 13s
# Wall time: 8min 36s

# %% [markdown]
# #### TODO: try input chr coord to get fasta from genome using bedtools

# %%
items = [ ('Scaffold102974', 0, 21560636),]
x = pybedtools.BedTool(items)
